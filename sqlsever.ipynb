-- %% [markdown]
-- # [QL_CUAHANGMAYTINH]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [QL_CUAHANGMAYTINH]    Script Date: 30/09/2025 12:32:55 AM ******/
CREATE DATABASE [QL_CUAHANGMAYTINH]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'QL_CUAHANGMAYTINH', FILENAME = N'G:\doanvb.VuAnhTuan.Th29.21\QL_CUAHANGMAYTINH.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'QL_CUAHANGMAYTINH_log', FILENAME = N'G:\doanvb.VuAnhTuan.Th29.21\QL_CUAHANGMAYTINH_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT, LEDGER = OFF
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET COMPATIBILITY_LEVEL = 160
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [QL_CUAHANGMAYTINH].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET ARITHABORT OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET  DISABLE_BROKER 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET  MULTI_USER 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET DB_CHAINING OFF 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET QUERY_STORE = ON
GO
ALTER DATABASE [QL_CUAHANGMAYTINH] SET QUERY_STORE (OPERATION_MODE = READ_WRITE, CLEANUP_POLICY = (STALE_QUERY_THRESHOLD_DAYS = 30), DATA_FLUSH_INTERVAL_SECONDS = 900, INTERVAL_LENGTH_MINUTES = 60, MAX_STORAGE_SIZE_MB = 1000, QUERY_CAPTURE_MODE = AUTO, SIZE_BASED_CLEANUP_MODE = AUTO, MAX_PLANS_PER_QUERY = 200, WAIT_STATS_CAPTURE_MODE = ON)
GO

-- %% [markdown]
-- # [dbo].[BAO_HANH]

-- %%
USE [QL_CUAHANGMAYTINH]
GO

-- %%
/****** Object:  Table [dbo].[BAO_HANH]    Script Date: 30/09/2025 12:32:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[BAO_HANH](
	[MaBaoHanh] [nvarchar](10) NOT NULL,
	[MaSanPham] [nvarchar](10) NULL,
	[MaKhachHang] [nvarchar](10) NULL,
	[NgayBatDau] [date] NULL,
	[NgayKetThuc] [date] NULL,
	[TrangThai] [nvarchar](50) NULL,
	[LoaiSanPham] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaBaoHanh] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CHI_TIET_HOA_DON]

-- %%
/****** Object:  Table [dbo].[CHI_TIET_HOA_DON]    Script Date: 30/09/2025 12:32:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CHI_TIET_HOA_DON](
	[MaChiTiet] [nvarchar](10) NOT NULL,
	[MaHoaDon] [nvarchar](10) NULL,
	[MaSanPham] [nvarchar](10) NULL,
	[SoLuong] [int] NULL,
	[GiaBan] [decimal](10, 2) NULL,
	[ThanhTien] [decimal](10, 2) NULL,
	[LoaiSanPham] [varchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaChiTiet] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[CHI_TIET_HOA_DON_NHAP]

-- %%
/****** Object:  Table [dbo].[CHI_TIET_HOA_DON_NHAP]    Script Date: 30/09/2025 12:32:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[CHI_TIET_HOA_DON_NHAP](
	[MaChiTietNhap] [nvarchar](10) NOT NULL,
	[MaHoaDonNhap] [nvarchar](10) NULL,
	[MaSanPham] [nvarchar](10) NULL,
	[SoLuong] [int] NOT NULL,
	[GiaNhap] [decimal](10, 2) NOT NULL,
	[ThanhTien] [decimal](10, 2) NOT NULL,
	[NgaySanXuat] [date] NULL,
	[HanSuDung] [date] NULL,
	[LoaiSanPham] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaChiTietNhap] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HOA_DON]

-- %%
/****** Object:  Table [dbo].[HOA_DON]    Script Date: 30/09/2025 12:32:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HOA_DON](
	[MaHoaDon] [nvarchar](10) NOT NULL,
	[MaKhachHang] [nvarchar](10) NULL,
	[MaNhanVien] [nvarchar](10) NULL,
	[NgayLap] [date] NULL,
	[TongTien] [decimal](10, 2) NULL,
	[LoaiSanPham] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaHoaDon] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[HOA_DON_NHAP]

-- %%
/****** Object:  Table [dbo].[HOA_DON_NHAP]    Script Date: 30/09/2025 12:32:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[HOA_DON_NHAP](
	[MaHoaDonNhap] [nvarchar](10) NOT NULL,
	[MaNhaCungCap] [nvarchar](10) NULL,
	[MaNhanVien] [nvarchar](10) NULL,
	[NgayNhap] [date] NOT NULL,
	[TongTien] [decimal](10, 2) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaHoaDonNhap] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[KHACH_HANG]

-- %%
/****** Object:  Table [dbo].[KHACH_HANG]    Script Date: 30/09/2025 12:32:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[KHACH_HANG](
	[MaKhachHang] [nvarchar](10) NOT NULL,
	[HoTen] [nvarchar](255) NULL,
	[SoDienThoai] [nvarchar](20) NULL,
	[Email] [nvarchar](255) NULL,
	[DiaChi] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaKhachHang] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[LOAI_SAN_PHAM]

-- %%
/****** Object:  Table [dbo].[LOAI_SAN_PHAM]    Script Date: 30/09/2025 12:32:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[LOAI_SAN_PHAM](
	[MaLoai] [nvarchar](10) NOT NULL,
	[TenLoai] [nvarchar](100) NULL,
	[MoTa] [nvarchar](255) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaLoai] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NHA_CUNG_CAP]

-- %%
/****** Object:  Table [dbo].[NHA_CUNG_CAP]    Script Date: 30/09/2025 12:32:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NHA_CUNG_CAP](
	[MaNhaCungCap] [nvarchar](10) NOT NULL,
	[TenNhaCungCap] [nvarchar](255) NOT NULL,
	[DiaChi] [nvarchar](255) NULL,
	[SoDienThoai] [nvarchar](20) NULL,
	[Email] [nvarchar](255) NULL,
	[NguoiLienHe] [nvarchar](255) NULL,
	[TrangThai] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaNhaCungCap] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[NHAN_VIEN]

-- %%
/****** Object:  Table [dbo].[NHAN_VIEN]    Script Date: 30/09/2025 12:32:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[NHAN_VIEN](
	[MaNhanVien] [nvarchar](10) NOT NULL,
	[TenNhanVien] [nvarchar](50) NOT NULL,
	[ChucVu] [nvarchar](30) NULL,
	[SoDienThoai] [nvarchar](15) NULL,
	[Email] [nvarchar](50) NULL,
	[Luong] [int] NULL,
PRIMARY KEY CLUSTERED 
(
	[MaNhanVien] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SAN_PHAM]

-- %%
/****** Object:  Table [dbo].[SAN_PHAM]    Script Date: 30/09/2025 12:32:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SAN_PHAM](
	[MaSanPham] [nvarchar](10) NOT NULL,
	[TenSanPham] [nvarchar](255) NULL,
	[MaLoai] [nvarchar](10) NULL,
	[GiaNhap] [decimal](10, 2) NULL,
	[GiaBan] [decimal](10, 2) NULL,
	[SoLuongTon] [int] NULL,
	[MoTa] [nvarchar](500) NULL,
	[TrangThai] [nvarchar](50) NULL,
PRIMARY KEY CLUSTERED 
(
	[MaSanPham] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TaiKhoan]

-- %%
/****** Object:  Table [dbo].[TaiKhoan]    Script Date: 30/09/2025 12:32:56 AM ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TaiKhoan](
	[TenDN] [nvarchar](50) NOT NULL,
	[MatKhau] [nvarchar](20) NULL,
 CONSTRAINT [PK_TaiKhoan] PRIMARY KEY CLUSTERED 
(
	[TenDN] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF__HOA_DON_N__TongT__6E565CE8]

-- %%
ALTER TABLE [dbo].[HOA_DON_NHAP] ADD  DEFAULT ((0)) FOR [TongTien]
GO

-- %% [markdown]
-- # [DF__NHA_CUNG___Trang__5E1FF51F]

-- %%
ALTER TABLE [dbo].[NHA_CUNG_CAP] ADD  DEFAULT (N'Hoạt động') FOR [TrangThai]
GO

-- %% [markdown]
-- # [DF__SAN_PHAM__TrangT__61F08603]

-- %%
ALTER TABLE [dbo].[SAN_PHAM] ADD  DEFAULT (N'Hoạt động') FOR [TrangThai]
GO

-- %% [markdown]
-- # [FK__BAO_HANH__MaKhac__75F77EB0]

-- %%
ALTER TABLE [dbo].[BAO_HANH]  WITH CHECK ADD FOREIGN KEY([MaKhachHang])
REFERENCES [dbo].[KHACH_HANG] ([MaKhachHang])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__BAO_HANH__MaSanP__75035A77]

-- %%
ALTER TABLE [dbo].[BAO_HANH]  WITH CHECK ADD FOREIGN KEY([MaSanPham])
REFERENCES [dbo].[SAN_PHAM] ([MaSanPham])
GO

-- %% [markdown]
-- # [FK__CHI_TIET___MaHoa__689D8392]

-- %%
ALTER TABLE [dbo].[CHI_TIET_HOA_DON]  WITH CHECK ADD FOREIGN KEY([MaHoaDon])
REFERENCES [dbo].[HOA_DON] ([MaHoaDon])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__CHI_TIET___MaSan__6991A7CB]

-- %%
ALTER TABLE [dbo].[CHI_TIET_HOA_DON]  WITH CHECK ADD FOREIGN KEY([MaSanPham])
REFERENCES [dbo].[SAN_PHAM] ([MaSanPham])
GO

-- %% [markdown]
-- # [FK__CHI_TIET___MaHoa__7132C993]

-- %%
ALTER TABLE [dbo].[CHI_TIET_HOA_DON_NHAP]  WITH CHECK ADD FOREIGN KEY([MaHoaDonNhap])
REFERENCES [dbo].[HOA_DON_NHAP] ([MaHoaDonNhap])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__CHI_TIET___MaSan__7226EDCC]

-- %%
ALTER TABLE [dbo].[CHI_TIET_HOA_DON_NHAP]  WITH CHECK ADD FOREIGN KEY([MaSanPham])
REFERENCES [dbo].[SAN_PHAM] ([MaSanPham])
GO

-- %% [markdown]
-- # [FK__HOA_DON__MaKhach__64CCF2AE]

-- %%
ALTER TABLE [dbo].[HOA_DON]  WITH CHECK ADD FOREIGN KEY([MaKhachHang])
REFERENCES [dbo].[KHACH_HANG] ([MaKhachHang])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__HOA_DON__MaNhanV__65C116E7]

-- %%
ALTER TABLE [dbo].[HOA_DON]  WITH CHECK ADD FOREIGN KEY([MaNhanVien])
REFERENCES [dbo].[NHAN_VIEN] ([MaNhanVien])
GO

-- %% [markdown]
-- # [FK__HOA_DON_N__MaNha__6C6E1476]

-- %%
ALTER TABLE [dbo].[HOA_DON_NHAP]  WITH CHECK ADD FOREIGN KEY([MaNhaCungCap])
REFERENCES [dbo].[NHA_CUNG_CAP] ([MaNhaCungCap])
ON DELETE CASCADE
GO

-- %% [markdown]
-- # [FK__HOA_DON_N__MaNha__6D6238AF]

-- %%
ALTER TABLE [dbo].[HOA_DON_NHAP]  WITH CHECK ADD FOREIGN KEY([MaNhanVien])
REFERENCES [dbo].[NHAN_VIEN] ([MaNhanVien])
GO

-- %% [markdown]
-- # [FK__SAN_PHAM__MaLoai__60FC61CA]

-- %%
ALTER TABLE [dbo].[SAN_PHAM]  WITH CHECK ADD FOREIGN KEY([MaLoai])
REFERENCES [dbo].[LOAI_SAN_PHAM] ([MaLoai])
GO

-- %% [markdown]
-- # [QL_CUAHANGMAYTINH]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [QL_CUAHANGMAYTINH] SET  READ_WRITE 
GO
